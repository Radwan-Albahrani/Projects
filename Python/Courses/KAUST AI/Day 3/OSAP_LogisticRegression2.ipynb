# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
def plotClass(X,y,p):
    plt.figure()
    for i in range(y.shape[1]):
        if y[0,i]==0:
            plt.plot(X[0,i],X[1,i],'r'+p)
        else:
            plt.plot(X[0,i],X[1,i],'b'+p)
            
    plt.show()

# %%
#Q1
num_data=1000 # data points per class

X=np.random.uniform(-1,1,[2,num_data])
y=X[0,:]**2+X[1,:]**2-0.5>0
y=(y[None,:]).astype(np.int8)
plotClass(X,y,'o')
print(X.shape)
print(y.shape)
# Out:
# (2, 1000)
# (1, 1000)

# %%
def get_z(W,X):
  return W @ X


def get_sigmoid(z):
  return 1/(1+np.exp(-z))

def get_loss(y,yhat):
  return np.sum(-y*np.log(yhat) - (1-y)*np.log(1-yhat), axis =1)


nb = 3
A=[]
for i in range(nb):
  for j in range(nb):
    A.append(X[0,:]**i * X[1,:]**j)


A = np.array(A)

ls =[]
lr = 0.0001
W = np.random.randn(1, A.shape[0])
for i in range(10000):
  z = get_z(W,A)
  yhat = get_sigmoid(z)
  loss = get_loss(y, yhat)

  ls.append(loss)

  dZ = yhat - y
  dW = dZ@A.T


  W -= lr*dW

# %%
plotClass(X, yhat>0.5,'o')
plotClass(X,y,'x')

# %%
import sklearn.linear_model as lm
import sklearn.preprocessing as preprocessing
import sklearn.pipeline as pipeline


pipeline = pipeline.Pipeline([('basis', preprocessing.PolynomialFeatures((2,8))), ('model', lm.LogisticRegression())])
pipeline.fit(X.T,y.reshape(-1,1))

yhat = pipeline.predict(X.T)

plotClass(X,yhat.reshape(1,-1),'o')
plotClass(X,y,'x')
# Out:
# c:\Users\radwa\AppData\Local\Programs\Python\Python310\lib\site-packages\sklearn\utils\validation.py:1111: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
#Q2
num_data=1000 # data points per class

X=np.random.uniform(-5,5,[2,num_data])
y=X[0,:]**2-X[1,:]**2-3>0
y=(y[None,:]).astype(np.int8)
plotClass(X,y,'o')
print(X.shape)
print(y.shape)
# Out:
# (2, 1000)
# (1, 1000)

# %%
def get_z(W,X):
  return W @ X


def get_sigmoid(z):
  return 1/(1+np.exp(-z))

def get_loss(y,yhat):
  return np.sum(-y*np.log(yhat) - (1-y)*np.log(1-yhat), axis =1)


nb = 3
A=[]
for i in range(nb):
  for j in range(nb):
    A.append((X[0,:]**i) * (X[1,:]**j))


A = np.array(A)

ls =[]
lr = 0.0001
W = np.random.randn(1, A.shape[0])
for i in range(10000):
  z = get_z(W,A)
  yhat = get_sigmoid(z)
  loss = get_loss(y, yhat)

  ls.append(loss)

  dZ = yhat - y
  dW = dZ@A.T


  W -= lr*dW

plotClass(X,yhat>0.5,'o')
plotClass(X,y,"o")
# Out:
# C:\Users\radwa\AppData\Local\Temp\ipykernel_15344\510347718.py:9: RuntimeWarning: divide by zero encountered in log
#   return np.sum(-y*np.log(yhat) - (1-y)*np.log(1-yhat), axis =1)
# C:\Users\radwa\AppData\Local\Temp\ipykernel_15344\510347718.py:9: RuntimeWarning: invalid value encountered in multiply
#   return np.sum(-y*np.log(yhat) - (1-y)*np.log(1-yhat), axis =1)
# C:\Users\radwa\AppData\Local\Temp\ipykernel_15344\510347718.py:6: RuntimeWarning: overflow encountered in exp
#   return 1/(1+np.exp(-z))

# %%
#Q3
num_data=1000 # data points per class

X=np.random.uniform(-5,5,[2,num_data])
y=5*X[0,:]**2+0.5*X[1,:]**2-20>0
y=(y[None,:]).astype(np.int8)
plotClass(X,y,'o')
print(X.shape)
print(y.shape)
# Out:
# (2, 1000)
# (1, 1000)

# %%
#Q4
num_data=1000 # data points per class

X=np.random.uniform(-5,5,[2,num_data])
y=10*np.exp(-X[0,:]**2)+X[1,:]**2-7>0
y=(y[None,:]).astype(np.int8)
plotClass(X,y,'o')
print(X.shape)
print(y.shape)
# Out:
# (2, 1000)
# (1, 1000)

# %%
#Q5
num_data=1000 # data points per class

X=np.random.uniform(-5,5,[2,num_data])
y=X[0,:]-20*X[1,:]**3>0
y=(y[None,:]).astype(np.int8)
plotClass(X,y,'o')
print(X.shape)
print(y.shape)
# Out:
# (2, 1000)
# (1, 1000)

# %%
#Q6
num_data=1000 # data points per class

X=np.random.uniform(-5,5,[2,num_data])
y=X[0,:]*X[1,:]>0
y=(y[None,:]).astype(np.int8)
plotClass(X,y,'o')
print(X.shape)
print(y.shape)
# Out:
# (2, 1000)
# (1, 1000)

# %%
#Q7
num_data=1000 # data points per class

X=np.random.uniform(-5,5,[2,num_data])
y=(np.floor(X[0,:]%2)==0)& (np.floor(X[1,:]%2)==0)>0
y=(y[None,:]).astype(np.int8)
plotClass(X,y,'o')
print(X.shape)
print(y.shape)
# Out:
# (2, 1000)
# (1, 1000)
